# %%
import pandas as pd
import os
import certifi
os.environ['SSL_CERT_FILE'] = certifi.where()
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df=df[0]
df
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
df=df.set_index('Symbol')
df
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ...                     ...                     ...
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
# ZBRA     Zebra Technologies  Information Technology
# ZBH           Zimmer Biomet             Health Care
# ZTS                  Zoetis             Health Care
#
#                                    GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM                         Industrial Conglomerates    Saint Paul, Minnesota
# AOS                                Building Products     Milwaukee, Wisconsin
# ABT                            Health Care Equipment  North Chicago, Illinois
# ...

# %% [markdown]
# ## Horizonatal addition (merge)

# %%
df1=df[['Security','GICS Sector','GICS Sub-Industry']]
df1
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ...                     ...                     ...
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
# ZBRA     Zebra Technologies  Information Technology
# ZBH           Zimmer Biomet             Health Care
# ZTS                  Zoetis             Health Care
#
#                                    GICS Sub-Industry
# Symbol
# MMM                         Industrial Conglomerates
# AOS                                Building Products
# ABT                            Health Care Equipment
# ABBV                                   Biotechnology
# ...

# %%
df2=df.iloc[:,-3:]
df2
# Out:
#         Date added      CIK      Founded
# Symbol
# MMM     1957-03-04    66740         1902
# AOS     2017-07-26    91142         1916
# ABT     1957-03-04     1800         1888
# ABBV    2012-12-31  1551152  2013 (1888)
# ACN     2011-07-06  1467373         1989
# ...            ...      ...          ...
# XYL     2011-11-01  1524472         2011
# YUM     1997-10-06  1041061         1997
# ZBRA    2019-12-23   877212         1969
# ZBH     2001-08-07  1136869         1927
# ZTS     2013-06-21  1555280         1952
#
# [503 rows x 3 columns]

# %%
pd.merge(df1,df2,on='Symbol')
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ...                     ...                     ...
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
# ZBRA     Zebra Technologies  Information Technology
# ZBH           Zimmer Biomet             Health Care
# ZTS                  Zoetis             Health Care
#
#                                    GICS Sub-Industry  Date added      CIK  \
# Symbol
# MMM                         Industrial Conglomerates  1957-03-04    66740
# AOS                                Building Products  2017-07-26    91142
# ABT                            Health Care Equipment  1957-03-04     1800
# ...

# %%
import numpy as np
np1=np.random.randint(100,200,25).reshape(5,5)
data1=pd.DataFrame(np1,index=['r1','r2','r3','r4','r5'],columns=['c1','c2','c3','c4','c5'])
data1
# Out:
#      c1   c2   c3   c4   c5
# r1  132  163  156  197  138
# r2  145  147  159  145  122
# r3  141  194  164  135  150
# r4  184  186  144  174  185
# r5  101  118  183  155  147

# %%
import numpy as np
np1=np.random.randint(1000,2000,25).reshape(5,5)
data2=pd.DataFrame(np1,index=['r1','r2','r3','r4','r6'],columns=['t1','t2','t3','t4','t5'])
data2
# Out:
#       t1    t2    t3    t4    t5
# r1  1222  1260  1980  1943  1910
# r2  1551  1891  1314  1504  1944
# r3  1134  1969  1498  1033  1751
# r4  1539  1080  1685  1044  1256
# r6  1023  1992  1335  1300  1895

# %%
data1.index.name='i1'
data2.index.name='i1'
pd.merge(data1,data2,on='i1',how='outer')
# Out:
#        c1     c2     c3     c4     c5      t1      t2      t3      t4      t5
# i1
# r1  132.0  163.0  156.0  197.0  138.0  1222.0  1260.0  1980.0  1943.0  1910.0
# r2  145.0  147.0  159.0  145.0  122.0  1551.0  1891.0  1314.0  1504.0  1944.0
# r3  141.0  194.0  164.0  135.0  150.0  1134.0  1969.0  1498.0  1033.0  1751.0
# r4  184.0  186.0  144.0  174.0  185.0  1539.0  1080.0  1685.0  1044.0  1256.0
# r5  101.0  118.0  183.0  155.0  147.0     NaN     NaN     NaN     NaN     NaN
# r6    NaN    NaN    NaN    NaN    NaN  1023.0  1992.0  1335.0  1300.0  1895.0

# %% [markdown]
# ## vertical addition

# %%
df
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ...                     ...                     ...
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
# ZBRA     Zebra Technologies  Information Technology
# ZBH           Zimmer Biomet             Health Care
# ZTS                  Zoetis             Health Care
#
#                                    GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM                         Industrial Conglomerates    Saint Paul, Minnesota
# AOS                                Building Products     Milwaukee, Wisconsin
# ABT                            Health Care Equipment  North Chicago, Illinois
# ...

# %%
df3=df.iloc[:100,:]
df3
# Out:
#                           Security             GICS Sector  \
# Symbol
# MMM                             3M             Industrials
# AOS                    A. O. Smith             Industrials
# ABT            Abbott Laboratories             Health Care
# ABBV                        AbbVie             Health Care
# ACN                      Accenture  Information Technology
# ...                            ...                     ...
# CNC            Centene Corporation             Health Care
# CNP             CenterPoint Energy               Utilities
# CF                   CF Industries               Materials
# CRL     Charles River Laboratories             Health Care
# SCHW    Charles Schwab Corporation              Financials
#
#                            GICS Sub-Industry      Headquarters Location  \
# Symbol
# MMM                 Industrial Conglomerates      Saint Paul, Minnesota
# AOS                        Building Products       Milwaukee, Wisconsin
# ...

# %%
df4=df.iloc[-100:,:]
df4
# Out:
#                      Security             GICS Sector  \
# Symbol
# ROP        Roper Technologies  Information Technology
# ROST              Ross Stores  Consumer Discretionary
# RCL     Royal Caribbean Group  Consumer Discretionary
# SPGI               S&P Global              Financials
# CRM                Salesforce  Information Technology
# ...                       ...                     ...
# XYL                Xylem Inc.             Industrials
# YUM               Yum! Brands  Consumer Discretionary
# ZBRA       Zebra Technologies  Information Technology
# ZBH             Zimmer Biomet             Health Care
# ZTS                    Zoetis             Health Care
#
#                                    GICS Sub-Industry  \
# Symbol
# ROP               Electronic Equipment & Instruments
# ROST                                  Apparel Retail
# RCL                   Hotels, Resorts & Cruise Lines
# SPGI                      Financial Exchanges & Data
# ...

# %%
pd.concat([df3,df4])
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ...                     ...                     ...
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
# ZBRA     Zebra Technologies  Information Technology
# ZBH           Zimmer Biomet             Health Care
# ZTS                  Zoetis             Health Care
#
#                                    GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM                         Industrial Conglomerates    Saint Paul, Minnesota
# AOS                                Building Products     Milwaukee, Wisconsin
# ABT                            Health Care Equipment  North Chicago, Illinois
# ...

# %%
np2=np.random.randint(100,200,25).reshape(5,5)
data3=pd.DataFrame(np1,index=['r1','r2','r3','r4','r5'],columns=['c1','c2','c3','c4','c5'])
data3
# Out:
#       c1    c2    c3    c4    c5
# r1  1222  1260  1980  1943  1910
# r2  1551  1891  1314  1504  1944
# r3  1134  1969  1498  1033  1751
# r4  1539  1080  1685  1044  1256
# r5  1023  1992  1335  1300  1895

# %%
np2=np.random.randint(100,200,25).reshape(5,5)
data4=pd.DataFrame(np1,index=['r6','r7','r8','r9','r10'],columns=['c1','c2','c3','c4','c6'])
data4
# Out:
#        c1    c2    c3    c4    c6
# r6   1222  1260  1980  1943  1910
# r7   1551  1891  1314  1504  1944
# r8   1134  1969  1498  1033  1751
# r9   1539  1080  1685  1044  1256
# r10  1023  1992  1335  1300  1895

# %%
pd.concat([data3,data4])
# Out:
#        c1    c2    c3    c4      c5      c6
# r1   1222  1260  1980  1943  1910.0     NaN
# r2   1551  1891  1314  1504  1944.0     NaN
# r3   1134  1969  1498  1033  1751.0     NaN
# r4   1539  1080  1685  1044  1256.0     NaN
# r5   1023  1992  1335  1300  1895.0     NaN
# r6   1222  1260  1980  1943     NaN  1910.0
# r7   1551  1891  1314  1504     NaN  1944.0
# r8   1134  1969  1498  1033     NaN  1751.0
# r9   1539  1080  1685  1044     NaN  1256.0
# r10  1023  1992  1335  1300     NaN  1895.0

# %%
df.rename(columns={'GICS Sub-Industry':'Industry'})
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ...                     ...                     ...
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
# ZBRA     Zebra Technologies  Information Technology
# ZBH           Zimmer Biomet             Health Care
# ZTS                  Zoetis             Health Care
#
#                                    GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM                         Industrial Conglomerates    Saint Paul, Minnesota
# AOS                                Building Products     Milwaukee, Wisconsin
# ABT                            Health Care Equipment  North Chicago, Illinois
# ...
