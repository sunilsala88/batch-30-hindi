# %%
import pandas as pd
import os
import certifi
os.environ['SSL_CERT_FILE'] = certifi.where()
df=pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average')[2]
print(df)
# Out:
#                Company Exchange Symbol                        Industry  \
# 0                   3M     NYSE    MMM                    Conglomerate
# 1     American Express     NYSE    AXP              Financial services
# 2                Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3               Amazon   NASDAQ   AMZN                       Retailing
# 4                Apple   NASDAQ   AAPL          Information technology
# 5               Boeing     NYSE     BA           Aerospace and defense
# 6          Caterpillar     NYSE    CAT         Construction and mining
# 7              Chevron     NYSE    CVX              Petroleum industry
# 8                Cisco   NASDAQ   CSCO          Information technology
# 9            Coca-Cola     NYSE     KO                  Drink industry
# 10              Disney     NYSE    DIS  Broadcasting and entertainment
# 11       Goldman Sachs     NYSE     GS              Financial services
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          30 non-null     object
#  1   Exchange         30 non-null     object
#  2   Symbol           30 non-null     object
#  3   Industry         30 non-null     object
#  4   Date added       30 non-null     object
#  5   Notes            5 non-null      object
#  6   Index weighting  30 non-null     object
# dtypes: object(7)
# memory usage: 1.8+ KB

# %%
df['Date added']=pd.to_datetime(df['Date added'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          30 non-null     object
#  1   Exchange         30 non-null     object
#  2   Symbol           30 non-null     object
#  3   Industry         30 non-null     object
#  4   Date added       30 non-null     datetime64[ns]
#  5   Notes            5 non-null      object
#  6   Index weighting  30 non-null     object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 1.8+ KB

# %%
df[df['Date added']>pd.to_datetime('2015-01-01')]
# Out:
#              Company Exchange Symbol                Industry Date added  \
# 2              Amgen   NASDAQ   AMGN       Biopharmaceutical 2020-08-31
# 3             Amazon   NASDAQ   AMZN               Retailing 2024-02-26
# 4              Apple   NASDAQ   AAPL  Information technology 2015-03-19
# 13         Honeywell   NASDAQ    HON            Conglomerate 2020-08-31
# 21            Nvidia   NASDAQ   NVDA  Information technology 2024-11-08
# 23        Salesforce     NYSE    CRM  Information technology 2020-08-31
# 24  Sherwin-Williams     NYSE    SHW    Speciality chemicals 2024-11-08
#
#                          Notes Index weighting
# 2                          NaN           3.89%
# 3                          NaN           3.21%
# 4                          NaN           3.25%
# 13  AlliedSignal and Honeywell           3.07%
# 21                         NaN           1.71%
# 23                         NaN           4.70%
# 24                         NaN           5.00%

# %%
pd.to_timedelta(365,unit='D')
# Out:
# Timedelta('365 days 00:00:00')

# %%
df
# Out:
#                Company Exchange Symbol                        Industry  \
# 0                   3M     NYSE    MMM                    Conglomerate
# 1     American Express     NYSE    AXP              Financial services
# 2                Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3               Amazon   NASDAQ   AMZN                       Retailing
# 4                Apple   NASDAQ   AAPL          Information technology
# 5               Boeing     NYSE     BA           Aerospace and defense
# 6          Caterpillar     NYSE    CAT         Construction and mining
# 7              Chevron     NYSE    CVX              Petroleum industry
# 8                Cisco   NASDAQ   CSCO          Information technology
# 9            Coca-Cola     NYSE     KO                  Drink industry
# 10              Disney     NYSE    DIS  Broadcasting and entertainment
# 11       Goldman Sachs     NYSE     GS              Financial services
# ...

# %%
df['Date added']+pd.to_timedelta(365,unit='D')
# Out:
# 0    1977-08-09
# 1    1983-08-30
# 2    2021-08-31
# 3    2025-02-25
# 4    2016-03-18
# 5    1988-03-11
# 6    1992-05-05
# 7    2009-02-18
# 8    2010-06-08
# 9    1988-03-11
# 10   1992-05-05
# 11   2014-09-23
# 12   2000-10-31
# 13   2021-08-31
# 14   1980-06-28
# 15   1998-03-17
# 16   1992-05-05
# 17   1986-10-30
# 18   1980-06-28
# 19   2000-10-31
# 20   2014-09-23
# 21   2025-11-08
# 22   1933-05-26
# 23   2021-08-31
# 24   2025-11-08
# 25   2010-06-08
# 26   2013-09-24
# 27   2005-04-08
# 28   2014-09-23
# 29   1998-03-17
# Name: Date added, dtype: datetime64[ns]

# %%
import yfinance as yf
data=yf.download('TSLA',period='7d',interval='1m')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                           Close        High         Low        Open  \
# Ticker                           TSLA        TSLA        TSLA        TSLA
# Datetime
# 2025-03-13 13:30:00+00:00  245.820007  248.289993  245.116104  248.125000
# 2025-03-13 13:31:00+00:00  244.925003  246.250000  244.100006  245.789993
# 2025-03-13 13:32:00+00:00  244.600006  245.800003  244.089996  244.850006
# 2025-03-13 13:33:00+00:00  243.565002  245.079300  243.565002  244.619995
# 2025-03-13 13:34:00+00:00  244.435394  245.039993  243.529999  243.589996
# ...                               ...         ...         ...         ...
# 2025-03-21 19:55:00+00:00  247.580002  249.050003  247.029999  248.960007
# 2025-03-21 19:56:00+00:00  247.960007  248.149994  247.600006  247.600006
# 2025-03-21 19:57:00+00:00  248.195007  248.615005  247.960007  247.960007
# 2025-03-21 19:58:00+00:00  248.860001  248.880005  248.160004  248.210007
# ...

# %%
# !pip install pendulum
# Out:
# ...
#   Using cached pendulum-3.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.9 kB)
# ...
#   Using cached time_machine-2.16.0-cp312-cp312-macosx_10_9_universal2.whl.metadata (21 kB)
# ...
# Using cached pendulum-3.0.0-cp312-cp312-macosx_11_0_arm64.whl (352 kB)
# Using cached time_machine-2.16.0-cp312-cp312-macosx_10_9_universal2.whl (20 kB)
# ...

# %%
import pendulum
time_zone= 'America/New_York'
tz1='Asia/Kolkata'
tz3='UTC'
print(pendulum.now(time_zone))
# Out:
# 2025-03-22 07:45:37.706686-04:00

# %%
pendulum.timezones()
# Out:
# ('Africa/Abidjan',
#  'Africa/Algiers',
#  'Africa/Bissau',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/El_Aaiun',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Khartoum',
#  'Africa/Lagos',
#  'Africa/Maputo',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Sao_Tome',
#  'Africa/Tripoli',
#  'Africa/Tunis',
#  'Africa/Windhoek',
#  'America/Adak',
#  'America/Anchorage',
#  'America/Araguaina',
#  'America/Argentina/Buenos_Aires',
#  'America/Argentina/Catamarca',
#  'America/Argentina/Cordoba',
#  'America/Argentina/Jujuy',
#  'America/Argentina/La_Rioja',
#  'America/Argentina/Mendoza',
#  'America/Argentina/Rio_Gallegos',
#  'America/Argentina/Salta',
#  'America/Argentina/San_Juan',
#  'America/Argentina/San_Luis',
#  'America/Argentina/Tucuman',
#  'America/Argentina/Ushuaia',
#  'America/Asuncion',
#  'America/Bahia',
#  'America/Bahia_Banderas',
#  'America/Barbados',
#  'America/Belem',
#  'America/Belize',
# ...

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2025-03-22 17:10:24.898389

# %%
data.info()
data.columns
l1=[]
for i in data.columns:
    l1.append(i[0])
data.columns= l1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2730 entries, 2025-03-13 13:30:00+00:00 to 2025-03-21 19:59:00+00:00
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, TSLA)   2730 non-null   float64
#  1   (High, TSLA)    2730 non-null   float64
#  2   (Low, TSLA)     2730 non-null   float64
#  3   (Open, TSLA)    2730 non-null   float64
#  4   (Volume, TSLA)  2730 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 128.0 KB

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#                       Datetime       Close        High         Low  \
# 0    2025-03-13 13:30:00+00:00  245.820007  248.289993  245.116104
# 1    2025-03-13 13:31:00+00:00  244.925003  246.250000  244.100006
# 2    2025-03-13 13:32:00+00:00  244.600006  245.800003  244.089996
# 3    2025-03-13 13:33:00+00:00  243.565002  245.079300  243.565002
# 4    2025-03-13 13:34:00+00:00  244.435394  245.039993  243.529999
# ...                        ...         ...         ...         ...
# 2725 2025-03-21 19:55:00+00:00  247.580002  249.050003  247.029999
# 2726 2025-03-21 19:56:00+00:00  247.960007  248.149994  247.600006
# 2727 2025-03-21 19:57:00+00:00  248.195007  248.615005  247.960007
# 2728 2025-03-21 19:58:00+00:00  248.860001  248.880005  248.160004
# 2729 2025-03-21 19:59:00+00:00  249.115005  249.490005  248.580002
#
#             Open   Volume
# 0     248.125000  7190091
# 1     245.789993   869249
# 2     244.850006   754477
# 3     244.619995   675276
# ...

# %% [markdown]
# # remove time zone

# %%
data['Datetime'].dt.tz_localize(None)
# Out:
# 0      2025-03-13 13:30:00
# 1      2025-03-13 13:31:00
# 2      2025-03-13 13:32:00
# 3      2025-03-13 13:33:00
# 4      2025-03-13 13:34:00
#                ...
# 2725   2025-03-21 19:55:00
# 2726   2025-03-21 19:56:00
# 2727   2025-03-21 19:57:00
# 2728   2025-03-21 19:58:00
# 2729   2025-03-21 19:59:00
# Name: Datetime, Length: 2730, dtype: datetime64[ns]

# %%
time_zone= 'America/New_York'
data['Datetime'].dt.tz_convert(time_zone).dt.tz_localize(None)
# Out:
# 0      2025-03-13 09:30:00
# 1      2025-03-13 09:31:00
# 2      2025-03-13 09:32:00
# 3      2025-03-13 09:33:00
# 4      2025-03-13 09:34:00
#                ...
# 2725   2025-03-21 15:55:00
# 2726   2025-03-21 15:56:00
# 2727   2025-03-21 15:57:00
# 2728   2025-03-21 15:58:00
# 2729   2025-03-21 15:59:00
# Name: Datetime, Length: 2730, dtype: datetime64[ns]
